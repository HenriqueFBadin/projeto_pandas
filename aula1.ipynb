# %% [markdown]
# # Projeto para aprendizado sobre análise de dados e pandas

# %% [markdown]
# ### Objetivo
#
# O objetivo deste projeto é análisar os empréstimos de cada seméstre, de 2010 a 2020, da biblioteca da UFRN. Com isso, espera-se desenvolver habilidades em análise de dados e pandas, além de desenvolver familiaridade com a ferramenta.

# %% [markdown]
# ### Adição, tratamento e análise básica dos dados

# %% [markdown]
# Adicionando os CSVs dos empréstimos de cada semestre da biblioteca da UFRN. Objetivo: Juntar todos os csvs em um único dataframe e fazer uma análise exploratória dos dados.

# %%
import pandas as pd

# %%
emp_20101 = pd.read_csv("./csvs/emprestimos-20101.csv")
emp_20102 = pd.read_csv("./csvs/emprestimos-20102.csv")
emp_20111 = pd.read_csv("./csvs/emprestimos-20111.csv")
emp_20112 = pd.read_csv("./csvs/emprestimos-20112.csv")
emp_20121 = pd.read_csv("./csvs/emprestimos-20121.csv")
emp_20122 = pd.read_csv("./csvs/emprestimos-20122.csv")
emp_20131 = pd.read_csv("./csvs/emprestimos-20131.csv")
emp_20132 = pd.read_csv("./csvs/emprestimos-20132.csv")
emp_20141 = pd.read_csv("./csvs/emprestimos-20141.csv")
emp_20142 = pd.read_csv("./csvs/emprestimos-20142.csv")
emp_20151 = pd.read_csv("./csvs/emprestimos-20151.csv")
emp_20152 = pd.read_csv("./csvs/emprestimos-20152.csv")
emp_20161 = pd.read_csv("./csvs/emprestimos-20161.csv")
emp_20162 = pd.read_csv("./csvs/emprestimos-20162.csv")
emp_20171 = pd.read_csv("./csvs/emprestimos-20171.csv")
emp_20172 = pd.read_csv("./csvs/emprestimos-20172.csv")
emp_20181 = pd.read_csv("./csvs/emprestimos-20181.csv")
emp_20182 = pd.read_csv("./csvs/emprestimos-20182.csv")
emp_20191 = pd.read_csv("./csvs/emprestimos-20191.csv")
emp_20192 = pd.read_csv("./csvs/emprestimos-20192.csv")
emp_20201 = pd.read_csv("./csvs/emprestimos-20201.csv")

# %%
pd.concat([emp_20101, emp_20102, emp_20111, emp_20112, emp_20121, emp_20122, emp_20131, emp_20132, emp_20141, emp_20142, emp_20151, emp_20152, emp_20161, emp_20162, emp_20171, emp_20172, emp_20181, emp_20182, emp_20191, emp_20192, emp_20201], ignore_index=True).to_csv("./csvs/emprestimos.csv", index=False)

# %%
emprestimos_unificados = pd.read_csv("./csvs/emprestimos.csv")

# %%
emprestimos_unificados.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %%
emprestimos_unificados.tail()
# Out:
#          id_emprestimo codigo_barras data_renovacao  \
# 2258013        2989086    2008047044            NaN
# 2258014        2989087    2008047047            NaN
# 2258015        2989088    2010052905            NaN
# 2258016        2989089    2010048023            NaN
# 2258017        2989090    2013106838            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 2258013  2020/05/05 19:51:06.059000000  2021/05/13 14:53:31.000000000
# 2258014  2020/05/05 19:51:06.135000000  2021/05/13 14:53:38.000000000
# 2258015  2020/05/05 19:51:06.164000000  2021/05/13 15:01:46.000000000
# 2258016  2020/06/09 11:54:02.669000000  2021/07/21 15:33:55.000000000
# 2258017  2020/06/09 11:54:02.852000000  2021/07/21 15:33:45.000000000
#
#          matricula_ou_siape             tipo_vinculo_usuario
# 2258013        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258014        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# ...

# %% [markdown]
# Compreendendo o tipo dos dados e retirando valores duplicados:

# %%
emprestimos_unificados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258018 entries, 0 to 2258017
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 120.6+ MB

# %%
emprestimos_unificados.drop_duplicates()
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 8               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ### Adicionando novos dados para aprofundar a análise

# %%
acervo = pd.read_parquet("./dados_exemplares.parquet")

# %%
acervo.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %% [markdown]
# ### Juntando os dados

# %%
merged_df = emprestimos_unificados.merge(acervo)

# %%
merged_df.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
merged_df = merged_df.drop(columns=['registro_sistema'])

# %%
merged_df.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# ### Manipulando tipos e atribuindo os números aos temas correspondentes

# %%
merged_df["matricula_ou_siape"] = merged_df.matricula_ou_siape.astype(str)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072558 entries, 0 to 2072557
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
# dtypes: int64(3), object(9)
# memory usage: 189.7+ MB

# %%
def localizar_tema(localizacao):
    if 0 <= localizacao <= 99:
        return 'Generalidades. Ciência e conhecimento.'
    elif 100 <= localizacao <= 199:
        return 'Filosofia e psicologia.'
    elif 200 <= localizacao <= 299:
        return 'Religião.'
    elif 300 <= localizacao <= 399:
        return 'Ciências sociais.'
    elif 400 <= localizacao <= 499:
        return 'Classe vaga. Provisoriamente não ocupada.'
    elif 500 <= localizacao <= 599:
        return 'Matemática e ciências naturais.'
    elif 600 <= localizacao <= 699:
        return 'Ciências aplicadas.'
    elif 700 <= localizacao <= 799:
        return 'Belas artes.'
    elif 800 <= localizacao <= 899:
        return 'Linguagem. Língua. Linguística.'
    elif 900 <= localizacao <= 999:
        return 'Geografia. Biografia. História.'
    else:
        return 'Localização desconhecida'

# %%
merged_df['tema'] = merged_df['localizacao'].map(localizar_tema)

# %%
merged_df.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
merged_df.tema.value_counts()
# Out:
# tema
# Ciências aplicadas.                       1425496
# Ciências sociais.                          369543
# Matemática e ciências naturais.             68745
# Generalidades. Ciência e conhecimento.      62525
# Religião.                                   62295
# Filosofia e psicologia.                     60564
# Geografia. Biografia. História.              7989
# Belas artes.                                 7911
# Linguagem. Língua. Linguística.              7490
# Name: count, dtype: int64

# %% [markdown]
# ## Analisando os empréstimos feitos

# %%
print(f"Total de empréstimos = {len(merged_df['id_emprestimo'].drop_duplicates())}")
# Out:
# Total de empréstimos = 2068724

# %%
merged_df['data_emprestimo'] = pd.to_datetime(merged_df['data_emprestimo'])

# %%
merged_df["ano_mes"] = merged_df["data_emprestimo"].dt.to_period('M')

# %%
merged_df["ano"] = merged_df["data_emprestimo"].dt.to_period('Y')

# %% [markdown]
# Desenvolvendo um dataframe de empréstimos feitos por ano e posteriormente por mês:

# %%
emprestimos_por_ano = merged_df.groupby('ano').size().reset_index(name='quantidade')
emprestimos_por_ano
# Out:
#      ano  quantidade
# 0   2010      161412
# 1   2011      196390
# 2   2012      221365
# 3   2013      234749
# 4   2014      219189
# 5   2015      213582
# 6   2016      215918
# 7   2017      218462
# 8   2018      194080
# 9   2019      171801
# 10  2020       25610

# %%
emprestimos_data = pd.DataFrame(merged_df['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_por_mes = emprestimos_data.groupby(by=emprestimos_data.data.dt.month).sum(numeric_only=True)
emprestimos_por_mes.index.name = 'mes'
emprestimos_por_mes
# Out:
#      quantidade
# mes
# 1         67542
# 2        210200
# 3        252185
# 4        208725
# 5        202530
# 6        138131
# 7        123790
# 8        232793
# 9        208234
# 10       188410
# 11       164222
# 12        75796

# %%
emprestimos_por_mes_ano = merged_df.groupby('ano_mes').size().reset_index(name='quantidade')
emprestimos_por_mes_ano
# Out:
#      ano_mes  quantidade
# 0    2010-01        4721
# 1    2010-02       10266
# 2    2010-03       19631
# 3    2010-04       16352
# 4    2010-05       15889
# ..       ...         ...
# 120  2020-01        3585
# 121  2020-02       10667
# 122  2020-03       11348
# 123  2020-05           8
# 124  2020-06           2
#
# [125 rows x 2 columns]

# %% [markdown]
# ### Visualização gráfica dos dados para facilitar a compreensão

# %%
import matplotlib.pyplot as plt
plt.plot(emprestimos_por_ano["ano"].astype(str), emprestimos_por_ano['quantidade'])
plt.xlabel('Ano')
plt.ylabel('Quantidade de Empréstimos')
plt.title('Quantidade de Empréstimos por Ano')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Como foi possível visualizar com a análise, os empréstimos de livros da biblioteca da UFRN tiveram uma queda significativa em 2020, provavelmente devido a pandemia do COVID-19. Entretanto, os números de empréstimo já demonstravam uma queda significante desde 2017.

# %%
plt.figure(figsize=(15, 5))
plt.plot(emprestimos_por_mes.index, emprestimos_por_mes['quantidade'])
plt.xlabel('Mês')
plt.ylabel('Quantidade de Empréstimos')
plt.title('Quantidade de exemplares emprestados do SISBI por mês entre 2010 e 2020')
plt.xticks(rotation=30)
plt.grid()
plt.show()

# %% [markdown]
# Outra abordagem para o mesmo problema:

# %%
merged_df['data_emprestimo'] = pd.to_datetime(merged_df['data_emprestimo'])

# Extrair o mês de cada empréstimo
merged_df['mes'] = merged_df['data_emprestimo'].dt.month

# Agrupar os dados por mês e contar os empréstimos
emprestimos_por_mes = merged_df.groupby('mes').size().reset_index(name='quantidade')

# Ordenar os meses com os maiores números de exemplares emprestados
top_mes_emprestimos = emprestimos_por_mes.sort_values(by='quantidade', ascending=False)

# Exibir os top 5 meses com os maiores números de exemplares emprestados
print(top_mes_emprestimos.head(12))
# Out:
#     mes  quantidade
# 2     3      252185
# 7     8      232793
# 1     2      210200
# 3     4      208725
# 8     9      208234
# 4     5      202530
# 9    10      188410
# 10   11      164222
# 5     6      138131
# 6     7      123790
# 11   12       75796
# 0     1       67542

# %%
plt.bar(top_mes_emprestimos["mes"], top_mes_emprestimos['quantidade'])
plt.xlabel('Mês')
plt.ylabel('Quantidade de Empréstimos')
plt.title('Quantidade de Empréstimos por Mês')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# A partir da análise do gráfico, das frequências de maior quantia de emprestimos a cada mês por ano, e a quantia total de empréstimos a cada mês nos últimos 10 anos, é possível afirmar que nos meses de março e agosto, a quantidade de empréstimos é maior. Como se trata de uma biblioteca universitária, os meses de janeiro, julho e dezembro possuirem os menores números por muito tem sentido lógico, já que é o período de férias.

# %% [markdown]
# ### Analisando a quantidade de empréstimos por hora no dia

# %%
merged_df['hora'] = merged_df['data_emprestimo'].dt.hour
emprestimos_por_hora = merged_df.groupby('hora').size().reset_index(name='quantidade')
emprestimos_por_hora
# Out:
#     hora  quantidade
# 0      0          17
# 1      6          14
# 2      7       18779
# 3      8      103420
# 4      9      131287
# 5     10      185847
# 6     11      180056
# 7     12      148754
# 8     13      126987
# 9     14      150876
# 10    15      166672
# 11    16      210655
# 12    17      185340
# 13    18      182520
# 14    19      102129
# 15    20      127716
# 16    21       51191
# 17    22         247
# 18    23          51

# %%
top_horarios_emprestimos = emprestimos_por_hora.sort_values(by='quantidade', ascending=False)
top_horarios_emprestimos
# Out:
#     hora  quantidade
# 11    16      210655
# 5     10      185847
# 12    17      185340
# 13    18      182520
# 6     11      180056
# 10    15      166672
# 9     14      150876
# 7     12      148754
# 4      9      131287
# 15    20      127716
# 8     13      126987
# 3      8      103420
# 14    19      102129
# 16    21       51191
# 2      7       18779
# 17    22         247
# 18    23          51
# 0      0          17
# 1      6          14

# %%
import numpy as np

norm = plt.Normalize(min(top_horarios_emprestimos['quantidade']), max(top_horarios_emprestimos['quantidade']))

# Definir o colormap
cmap = plt.cm.Reds

# Obter as cores para cada barra
colors = cmap(norm(top_horarios_emprestimos['quantidade']))

# Plotar o gráfico de barras com as cores variando conforme a quantidade
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(top_horarios_emprestimos['hora'], top_horarios_emprestimos['quantidade'], color=colors)
ax.set_xlabel('Hora do Dia')
ax.set_ylabel('Quantidade de Empréstimos')
ax.set_title('Quantidade de Empréstimos por Hora do Dia')
ax.set_xticks(range(0, 24))
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Adicionar a colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, label='Quantidade de Empréstimos')

plt.show()

# %% [markdown]
# Às 16 horas definitivamente é o horário de pico para empréstimos de livros na biblioteca da UFRN. Em seguida, às 10, 11, 17 e 18 horas, existe também uma grande quantidade de empréstimos.

# %%
merged_df.tipo_vinculo_usuario.value_counts(normalize=True)
# Out:
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                 0.777952
# ALUNO DE PÓS-GRADUAÇÃO             0.145978
# DOCENTE                            0.034248
# SERVIDOR TÉCNICO-ADMINISTRATIVO    0.015529
# ALUNO MÉDIO/TÉCNICO                0.013525
# DOCENTE EXTERNO                    0.011555
# USUÁRIO EXTERNO                    0.001211
# OUTROS                             0.000002
# Name: proportion, dtype: float64

# %% [markdown]
# Como podemos visualizar, a quantidade de empréstimos de livros na biblioteca da UFRN é, em sua maioria, feita por alunos de graduação, sendo eles 77.8% do total dos empréstimos. Em seguida, temos os alunos de pós-graduação, com 14.6%. Ou seja, a biblioteca é mais utilizada por alunos da instituição. Dessa forma, a biblioteca deve aderir uma estratégia condisente com este público.

# %%
merged_df.colecao.value_counts(normalize=True)
# Out:
# colecao
# Acervo Circulante                        0.990639
# Multimeios                               0.003838
# Monografias                              0.001940
# Dissertações                             0.001161
# Obras de Referência                      0.000943
# Publicações de Autores do RN             0.000418
# Publicações da UFRN                      0.000369
# Teses                                    0.000345
# Folhetos                                 0.000131
# Necessidades Educacionais Específicas    0.000063
# Trabalho Acadêmico                       0.000055
# Eventos                                  0.000049
# Coleção Mossoroense                      0.000021
# Coleção Zila Mamede                      0.000014
# Literatura de Cordel                     0.000012
# Obras Raras                              0.000004
# Name: proportion, dtype: float64

# %% [markdown]
# As coleções que derivam do acervo circulante da biblioteca são de uma maioria esmagadora de 99%, enquanto as outras diversas coleções representam apensa 1%. Ou seja, a biblioteca deve focar em melhorar a qualidade do acervo circulante, já que é o mais utilizado.

# %%
merged_df.biblioteca.value_counts(normalize=True)
# Out:
# biblioteca
# Biblioteca Central Zila Mamede                                                              0.688110
# Biblioteca Setorial do Centro Ciências da Saúde - CCS                                       0.057232
# Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz       0.037446
# Biblioteca Setorial Prof. Alberto Moreira Campos - ­Departamento de Odontologia             0.032063
# Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - ­CERES­ - Caicó                   0.029663
# Biblioteca Setorial Bertha Cruz Enders - ­Escola de Saúde da UFRN - ESUFRN                  0.022214
# Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA                   0.019660
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó                                     0.015487
# Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos                 0.014035
# ...

# %% [markdown]
# Pelo tamanho da biblioteca Central perante as demais é natural o maior número de empréstimos.
#
# Outras métricas poderiam ser utilizadas para determinar o sucesso da biblioteca, como:
# - A quantidade esperada de empréstimos.
# - Quantidade de empréstimos por usuário cadastrado em cada biblioteca.
# - Ações e investimentos realizados em cada uma.

# %%
merged_df.tema.value_counts(normalize=True)
# Out:
# tema
# Ciências aplicadas.                       0.687795
# Ciências sociais.                         0.178303
# Matemática e ciências naturais.           0.033169
# Generalidades. Ciência e conhecimento.    0.030168
# Religião.                                 0.030057
# Filosofia e psicologia.                   0.029222
# Geografia. Biografia. História.           0.003855
# Belas artes.                              0.003817
# Linguagem. Língua. Linguística.           0.003614
# Name: proportion, dtype: float64

# %% [markdown]
# A área de ciências aplicadas possui uma grande dominância perante as demais. É necessário de alguns estudos para entender o motivo dessa grande diferença.

# %%
alunos_grad = merged_df.loc[merged_df['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO']

# %%
alunos_grad.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1600182
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %%
alunos_grad.colecao.value_counts(normalize=True)
# Out:
# colecao
# Acervo Circulante                        0.992453
# Multimeios                               0.002885
# Monografias                              0.002215
# Dissertações                             0.000714
# Obras de Referência                      0.000649
# Publicações de Autores do RN             0.000369
# Publicações da UFRN                      0.000289
# Teses                                    0.000152
# Folhetos                                 0.000112
# Trabalho Acadêmico                       0.000050
# Necessidades Educacionais Específicas    0.000045
# Eventos                                  0.000035
# Coleção Mossoroense                      0.000011
# Coleção Zila Mamede                      0.000009
# Literatura de Cordel                     0.000007
# Obras Raras                              0.000004
# Name: proportion, dtype: float64

# %%
alunos_grad_acervo = alunos_grad.loc[alunos_grad['colecao'] == 'Acervo Circulante'].copy()
alunos_grad_acervo["mes"] = alunos_grad_acervo["data_emprestimo"].dt.month
alunos_grad_acervo["ano"] = alunos_grad_acervo["data_emprestimo"].dt.year.astype(int)

alunos_grad_ano_mes = alunos_grad_acervo.loc[:, ["mes", "ano"]]

# %%
alunos_grad_ano_mes = alunos_grad_ano_mes.value_counts().reset_index(name='quantidade')
alunos_grad_ano_mes
# Out:
#      mes   ano  quantidade
# 0      3  2012       22797
# 1      3  2015       22483
# 2      4  2013       21853
# 3      3  2017       21735
# 4      3  2016       21692
# ..   ...   ...         ...
# 118    1  2017        2671
# 119    1  2019        2276
# 120   12  2019        1980
# 121    1  2020        1781
# 122    1  2011         809
#
# [123 rows x 3 columns]

# %%
from matplotlib import ticker
import seaborn as sns


def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)                    
  plt.figure(figsize=(10,6))                                                           

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')                                           
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel(None)                                                                     
  plt.ylabel(None)                                                                    

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gera_box_plot(alunos_grad_ano_mes,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %%
alunos_pos = merged_df.loc[merged_df['tipo_vinculo_usuario'] == 'ALUNO DE PÓS-GRADUAÇÃO']
alunos_pos_acervo = alunos_pos.loc[alunos_pos['colecao'] == 'Acervo Circulante'].copy()
alunos_pos_acervo["mes"] = alunos_pos_acervo["data_emprestimo"].dt.month
alunos_pos_acervo["ano"] = alunos_pos_acervo["data_emprestimo"].dt.year.astype(int)

alunos_pos_ano_mes = alunos_pos_acervo.loc[:, ["mes", "ano"]]
alunos_pos_ano_mes = alunos_pos_ano_mes.value_counts().reset_index(name='quantidade')
alunos_pos_ano_mes
# Out:
#      mes   ano  quantidade
# 0      3  2015        3927
# 1      8  2017        3837
# 2      3  2017        3722
# 3      3  2016        3711
# 4      8  2016        3662
# ..   ...   ...         ...
# 119    1  2020        1143
# 120    1  2010        1106
# 121   12  2019        1069
# 122    1  2011         465
# 123    6  2020           2
#
# [124 rows x 3 columns]

# %%
gera_box_plot(alunos_pos_ano_mes,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de pós graduação no acervo circulante')

# %%
excel_ate_2010 = pd.read_excel("./dia6/matricula_alunos.xlsx", sheet_name="Até 2010", skiprows=1)
excel_pos_2010 = pd.read_excel("./dia6/matricula_alunos.xlsx", sheet_name="Após 2010",skiprows=1)
json = pd.read_json("./dia6/cadastro_alunos.json")

# %%
excel_ate_2010.head()
# Out:
#    Número da matrícula     Tipo de vinculo                Curso
# 0          190001688.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1          199014489.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2          199735674.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3          199812431.0  ALUNO DE GRADUAÇÃO               LETRAS
# 4          199823670.0  ALUNO DE GRADUAÇÃO             ECOLOGIA

# %%
excel_pos_2010.head()
# Out:
#      Matricula      Tipo de vinculo                Cursos
# 0  2.010000e+09  ALUNO DE GRADUAÇÃO               DIREITO
# 1  2.010000e+09  ALUNO DE GRADUAÇÃO             AGRONOMIA
# 2  2.010001e+09  ALUNO DE GRADUAÇÃO    ENGENHARIA QUÍMICA
# 3  2.010003e+09  ALUNO DE GRADUAÇÃO  ENGENHARIA AMBIENTAL
# 4  2.010003e+09  ALUNO DE GRADUAÇÃO             GEOGRAFIA

# %%
json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
excel_ate_2010.columns = ['matricula', 'vinculo', 'curso']

# %%
excel_pos_2010.columns = ['matricula', 'vinculo', 'curso']

# %%
matriculas_excel = pd.concat([excel_ate_2010, excel_pos_2010])

# %%
matriculas_excel.matricula = matriculas_excel.matricula.astype(str)

# %%
matriculas_excel.tail()
# Out:
#           matricula             vinculo                     curso
# 2269  20150116770.0  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270   2015074523.0  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  20160002745.0  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  20170086533.0  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  20180090351.0  ALUNO DE GRADUAÇÃO                     DANÇA

# %%
matriculas_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 2273
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   matricula  10000 non-null  object
#  1   vinculo    10000 non-null  object
#  2   curso      10000 non-null  object
# dtypes: object(3)
# memory usage: 312.5+ KB

# %%
json_grad = pd.read_json(json.registros[0])
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_22956\168734160.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   json_grad = pd.read_json(json.registros[0])

# %%
json_grad
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
json_grad.matricula_ou_siape = json_grad.matricula_ou_siape.astype('float')
json_grad.matricula_ou_siape = json_grad.matricula_ou_siape.astype('string')

# %%
json_grad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %%
json_grad.columns = ['matricula', 'vinculo', 'curso']

# %%
cadastro_usuarios_cursos = pd.concat([matriculas_excel, json_grad],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#            matricula             vinculo                 curso
# 0        190001688.0  ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1        199014489.0  ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2        199735674.0  ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3        199812431.0  ALUNO DE GRADUAÇÃO                LETRAS
# 4        199823670.0  ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...              ...                 ...                   ...
# 72797  20200012706.0  ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798  20200039601.0  ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799  20200132517.0  ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800  20200009344.0  ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801  20200090284.0  ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %%
cadastro_usuarios_cursos.vinculo.value_counts()
# Out:
# vinculo
# ALUNO DE GRADUAÇÃO    72802
# Name: count, dtype: int64

# %%
alunos_de_grad = merged_df.loc[merged_df['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO']

# %%
emprestimos_pos2015_grad = alunos_de_grad.loc[:, ['matricula_ou_siape', 'data_emprestimo']].loc[alunos_de_grad['data_emprestimo'] > '2015'].reset_index(drop=True)

# %%
emprestimos_pos2015_grad
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013021576.0 2015-01-02 09:16:49.566
# 1            2014026648.0 2015-01-02 09:44:42.808
# 2            2014026648.0 2015-01-02 09:44:43.127
# 3            2010049586.0 2015-01-02 10:11:09.837
# 4            2014021454.0 2015-01-02 10:19:38.087
# ...                   ...                     ...
# 788109      20190154579.0 2020-03-18 16:26:20.477
# 788110      20160129109.0 2020-03-18 16:41:28.500
# 788111      20160129109.0 2020-03-18 16:41:28.588
# 788112      20160129109.0 2020-03-18 16:41:28.662
# 788113      20160129109.0 2020-03-18 16:41:28.713
#
# [788114 rows x 2 columns]

# %%
emprestimos_pos2015_grad.isnull().sum()
# Out:
# matricula_ou_siape    0
# data_emprestimo       0
# dtype: int64

# %%
cursos_selecionados = ['BIBLIOTECONOMIA','CIÊNCIAS SOCIAIS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']
cadastro_usuarios_cursos_selecionados = cadastro_usuarios_cursos.loc[cadastro_usuarios_cursos["curso"].isin(cursos_selecionados)]

# %%
cadastro_usuarios_cursos_selecionados
# Out:
#            matricula             vinculo             curso
# 8        200031011.0  ALUNO DE GRADUAÇÃO           DIREITO
# 9        200045080.0  ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15       200115053.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18       200123382.0  ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19       200123730.0  ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...              ...                 ...               ...
# 72789  20200097481.0  ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72796  20200107087.0  ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72797  20200012706.0  ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72800  20200009344.0  ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72801  20200090284.0  ALUNO DE GRADUAÇÃO           DIREITO
#
# [18833 rows x 3 columns]

# %%
emprestimos_pos2015_grad.columns = ['matricula', 'data_emprestimo']

# %%
cadastro_usuarios_cursos_selecionados = emprestimos_pos2015_grad.merge(cadastro_usuarios_cursos_selecionados)
cadastro_usuarios_cursos_selecionados
# Out:
#             matricula         data_emprestimo             vinculo  \
# 0        2014021454.0 2015-01-02 10:19:38.087  ALUNO DE GRADUAÇÃO
# 1        2013018187.0 2015-01-02 10:25:40.883  ALUNO DE GRADUAÇÃO
# 2        2014029499.0 2015-01-02 12:26:43.571  ALUNO DE GRADUAÇÃO
# 3        2014029499.0 2015-01-02 12:26:43.840  ALUNO DE GRADUAÇÃO
# 4        2014029499.0 2015-01-02 12:26:44.750  ALUNO DE GRADUAÇÃO
# ...               ...                     ...                 ...
# 212834  20200090284.0 2020-03-17 20:23:54.966  ALUNO DE GRADUAÇÃO
# 212835  20180113385.0 2020-03-17 21:20:47.278  ALUNO DE GRADUAÇÃO
# 212836  20190150079.0 2020-03-18 13:43:53.220  ALUNO DE GRADUAÇÃO
# 212837  20190150079.0 2020-03-18 13:43:53.389  ALUNO DE GRADUAÇÃO
# 212838  20190150079.0 2020-03-18 13:43:53.456  ALUNO DE GRADUAÇÃO
#
#                    curso
# 0              FILOSOFIA
# 1                DIREITO
# 2       CIÊNCIAS SOCIAIS
# 3       CIÊNCIAS SOCIAIS
# 4       CIÊNCIAS SOCIAIS
# ...

# %%
cadastro_usuarios_cursos_selecionados.data_emprestimo = cadastro_usuarios_cursos_selecionados.data_emprestimo.dt.year
emprestimos_cursos_selecionados = cadastro_usuarios_cursos_selecionados.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_cursos_selecionados.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_cursos_selecionados
# Out:
#      ANO               CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017  COMUNICAÇÃO SOCIAL                    8253
# 1   2016  COMUNICAÇÃO SOCIAL                    7973
# 2   2017             DIREITO                    7885
# 3   2015     BIBLIOTECONOMIA                    7784
# 4   2015             DIREITO                    7665
# 5   2016           FILOSOFIA                    7576
# 6   2015    CIÊNCIAS SOCIAIS                    7489
# 7   2017           PEDAGOGIA                    7434
# 8   2017           FILOSOFIA                    7389
# 9   2016             DIREITO                    7363
# 10  2017     BIBLIOTECONOMIA                    7307
# 11  2015           PEDAGOGIA                    7189
# 12  2016           PEDAGOGIA                    7153
# 13  2015  COMUNICAÇÃO SOCIAL                    7147
# 14  2016     BIBLIOTECONOMIA                    7044
# 15  2018             DIREITO                    7027
# 16  2016    CIÊNCIAS SOCIAIS                    6979
# ...

# %%
emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS',
        fill_value = '-',
        aggfunc= sum,
        margins = True,
        margins_name = 'TOTAL',
)
emprestimos_tipo_usuario_curso_pivot
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_22956\4016683961.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
# C:\Users\henri\AppData\Local\Temp\ipykernel_22956\4016683961.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
# ...

# %%
matriculas_excel
# Out:
#           matricula             vinculo                     curso
# 0       190001688.0  ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1       199014489.0  ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2       199735674.0  ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3       199812431.0  ALUNO DE GRADUAÇÃO                    LETRAS
# 4       199823670.0  ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...             ...                 ...                       ...
# 2269  20150116770.0  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270   2015074523.0  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  20160002745.0  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  20170086533.0  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  20180090351.0  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %%
json_pos = pd.read_json(json.registros[1])
json_pos.columns = ['matricula', 'vinculo', 'curso']
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_22956\3657780278.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   json_pos = pd.read_json(json.registros[1])

# %%
usuarios_cursos = pd.concat([matriculas_excel, json_pos],ignore_index=True)
print(usuarios_cursos.shape)
usuarios_cursos.head()
# Out:
# (29440, 3)
#      matricula             vinculo                curso
# 0  190001688.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1  199014489.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2  199735674.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3  199812431.0  ALUNO DE GRADUAÇÃO               LETRAS
# 4  199823670.0  ALUNO DE GRADUAÇÃO             ECOLOGIA

# %%
usuarios_cursos_pos_graduacao = usuarios_cursos.loc[usuarios_cursos["vinculo"] == "ALUNO DE PÓS-GRADUAÇÃO"]

# %%
matricula_data_de_emprestimo_pos_graduacao = merged_df.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo_pos_graduacao = matricula_data_de_emprestimo_pos_graduacao.query('data_emprestimo > 2017')
matricula_data_de_emprestimo_pos_graduacao = matricula_data_de_emprestimo_pos_graduacao.reset_index(drop=True)
matricula_data_de_emprestimo_pos_graduacao.columns = ['matricula', 'data_emprestimo']
matricula_data_de_emprestimo_pos_graduacao
# Out:
#             matricula         data_emprestimo
# 0        2014035816.0 2017-01-02 08:01:14.113
# 1       20161011168.0 2017-01-02 08:29:46.722
# 2       20161011168.0 2017-01-02 08:29:46.794
# 3       20161011168.0 2017-01-02 08:46:42.991
# 4       20161011168.0 2017-01-02 08:46:43.400
# ...               ...                     ...
# 609948      3067431.0 2020-05-05 19:51:06.059
# 609949      3067431.0 2020-05-05 19:51:06.135
# 609950      3067431.0 2020-05-05 19:51:06.164
# 609951  20201014993.0 2020-06-09 11:54:02.669
# 609952  20201014993.0 2020-06-09 11:54:02.852
#
# [609953 rows x 2 columns]

# %%
usuarios_cursos_pos_graduacao.matricula = usuarios_cursos_pos_graduacao.matricula.astype(float)
usuarios_cursos_pos_graduacao.matricula = usuarios_cursos_pos_graduacao.matricula.astype(str)
# Out:
# C:\Users\henri\AppData\Local\Temp\ipykernel_22956\3310776097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usuarios_cursos_pos_graduacao.matricula = usuarios_cursos_pos_graduacao.matricula.astype(float)
# C:\Users\henri\AppData\Local\Temp\ipykernel_22956\3310776097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usuarios_cursos_pos_graduacao.matricula = usuarios_cursos_pos_graduacao.matricula.astype(str)

# %%
usuarios_cursos_pos_graduacao
# Out:
#            matricula                 vinculo  \
# 10000   2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 10001   2008106583.0  ALUNO DE PÓS-GRADUAÇÃO
# 10002   2011101417.0  ALUNO DE PÓS-GRADUAÇÃO
# 10003   2011113122.0  ALUNO DE PÓS-GRADUAÇÃO
# 10004   2010110903.0  ALUNO DE PÓS-GRADUAÇÃO
# ...              ...                     ...
# 29435  20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 29436  20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 29437  20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 29438  20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 29439  20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 10000                  CIÊNCIAS ODONTOLÓGICAS
# 10001                  ENGENHARIA DE SOFTWARE
# 10002                 ARQUITETURA E URBANISMO
# 10003                               FILOSOFIA
# 10004                           ARTES CÊNICAS
# ...                                       ...
# 29435  GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# ...

# %%
matricula_data_de_emprestimo_pos_graduacao.matricula = matricula_data_de_emprestimo_pos_graduacao.matricula.astype(float)
matricula_data_de_emprestimo_pos_graduacao.matricula = matricula_data_de_emprestimo_pos_graduacao.matricula.astype(str)

# %%
matricula_data_de_emprestimo_pos_graduacao
# Out:
#             matricula         data_emprestimo
# 0        2014035816.0 2017-01-02 08:01:14.113
# 1       20161011168.0 2017-01-02 08:29:46.722
# 2       20161011168.0 2017-01-02 08:29:46.794
# 3       20161011168.0 2017-01-02 08:46:42.991
# 4       20161011168.0 2017-01-02 08:46:43.400
# ...               ...                     ...
# 609948      3067431.0 2020-05-05 19:51:06.059
# 609949      3067431.0 2020-05-05 19:51:06.135
# 609950      3067431.0 2020-05-05 19:51:06.164
# 609951  20201014993.0 2020-06-09 11:54:02.669
# 609952  20201014993.0 2020-06-09 11:54:02.852
#
# [609953 rows x 2 columns]

# %%
emprestimos_pos_graduacao_desde_2017 = matricula_data_de_emprestimo_pos_graduacao.merge(usuarios_cursos_pos_graduacao, on='matricula')
emprestimos_pos_graduacao_desde_2017
# Out:
#            matricula         data_emprestimo                 vinculo  \
# 0      20161011168.0 2017-01-02 08:29:46.722  ALUNO DE PÓS-GRADUAÇÃO
# 1      20161011168.0 2017-01-02 08:29:46.794  ALUNO DE PÓS-GRADUAÇÃO
# 2      20161011168.0 2017-01-02 08:46:42.991  ALUNO DE PÓS-GRADUAÇÃO
# 3      20161011168.0 2017-01-02 08:46:43.400  ALUNO DE PÓS-GRADUAÇÃO
# 4      20161013903.0 2017-01-02 09:41:45.823  ALUNO DE PÓS-GRADUAÇÃO
# ...              ...                     ...                     ...
# 92057  20191017055.0 2020-03-19 14:41:57.754  ALUNO DE PÓS-GRADUAÇÃO
# 92058  20191017055.0 2020-03-19 14:42:56.670  ALUNO DE PÓS-GRADUAÇÃO
# 92059  20191017055.0 2020-03-19 14:43:40.666  ALUNO DE PÓS-GRADUAÇÃO
# 92060  20201014993.0 2020-06-09 11:54:02.669  ALUNO DE PÓS-GRADUAÇÃO
# 92061  20201014993.0 2020-06-09 11:54:02.852  ALUNO DE PÓS-GRADUAÇÃO
#
#                   curso
# 0             FILOSOFIA
# 1             FILOSOFIA
# 2             FILOSOFIA
# 3             FILOSOFIA
# ...

# %%
emprestimos_pos_graduacao_desde_2017.data_emprestimo = emprestimos_pos_graduacao_desde_2017.data_emprestimo.dt.year

# %%
emprestimos_pos_graduacao_desde_2017 = emprestimos_pos_graduacao_desde_2017.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_pos_graduacao_desde_2017.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_pos_graduacao_desde_2017.head()
# Out:
#     ANO                           CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2018          CIÊNCIAS ODONTOLÓGICAS                    2540
# 1  2017                   ADMINISTRAÇÃO                    2538
# 2  2017          ENGENHARIA DE SOFTWARE                    2477
# 3  2017               CIÊNCIAS DA SAÚDE                    2434
# 4  2017  CIÊNCIA, TECNOLOGIA E INOVAÇÃO                    2415

# %%
emprestimos_pos_graduacao_e_curso_pivot = emprestimos_pos_graduacao_desde_2017.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS'
)
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0
# DESIGN                                  2272.0  1838.0  1841.0  254.0
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0
# ENGENHARIA DE SOFTWARE                  2477.0  2222.0  1887.0  264.0
# ...

# %%
previsao_2022 = pd.read_table('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_7-Apresentando_resultados_em_HTML/Dataset/previsao')

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)
previsao_2022
# Out:
#                                          0     1
# 0                            administracao  1905
# 1                  arquitetura_e_urbanismo  1896
# 2                            artes_cenicas  1920
# 3                           bioinformatica  2302
# 4                               bioquimica  2090
# 5        ciencia_e_engenharia_de_materiais  2010
# 6            ciencia_tecnologia_e_inovacao  1960
# 7                        ciencias_da_saude  1730
# 8                   ciencias_odontologicas  2405
# 9                                   design  1900
# 10                        engenharia_civil  1920
# 11                     engenharia_software  1890
# 12                               filosofia  1903
# 13  gestao_da_informacao_e_do_conhecimento  1855

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0
# DESIGN                                  2272.0  1838.0  1841.0  254.0
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0
# ENGENHARIA DE SOFTWARE                  2477.0  2222.0  1887.0  264.0
# ...

# %%
previsao_2022.index = emprestimos_pos_graduacao_e_curso_pivot.index
emprestimos_pos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0  1905
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0  1896
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0  1920
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0  2302
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0  1960
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0  2405
# DESIGN                                  2272.0  1838.0  1841.0  254.0  1900
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0  1920
# ...

# %%
emprestimos_pos_graduacao_e_curso_pivot['2022'] = emprestimos_pos_graduacao_e_curso_pivot['2022'].astype('int')
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0  1905
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0  1896
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0  1920
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0  2302
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0  1960
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0  2405
# DESIGN                                  2272.0  1838.0  1841.0  254.0  1900
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0  1920
# ...

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)

# %%
percentual_2018 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,0])
percentual_2019 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1])
percentual_2022 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,3],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2])

# %%
percentual = pd.DataFrame({'2018':percentual_2018,
                           '2019':percentual_2019,
                           '2022':percentual_2022})
percentual
# Out:
#                                          2018   2019   2022
# CURSO
# ADMINISTRAÇÃO                           -8.75 -26.94 -84.10
# ARQUITETURA E URBANISMO                -13.22  -5.16 -85.86
# ARTES CÊNICAS                           -1.56 -12.97 -87.36
# BIOINFORMÁTICA                         -12.60  -4.65 -85.59
# BIOQUÍMICA                             -15.26   5.81 -86.78
# CIÊNCIA E ENGENHARIA DE MATERIAIS       -8.89  -4.83 -83.67
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          -2.07 -14.33 -85.04
# CIÊNCIAS DA SAÚDE                      -18.41  -8.11 -87.18
# CIÊNCIAS ODONTOLÓGICAS                   5.22 -15.98 -83.51
# DESIGN                                 -19.10   0.16 -86.20
# ENGENHARIA CIVIL                       -12.92  -4.79 -87.23
# ENGENHARIA DE SOFTWARE                 -10.29 -15.08 -86.01
# FILOSOFIA                               -5.62 -13.43 -82.97
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -16.55  -6.35 -85.77

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()
percentual
# Out:
#                                      Curso   2018   2019   2022
# 0                            Administração  -8.75 -26.94 -84.10
# 1                  Arquitetura e urbanismo -13.22  -5.16 -85.86
# 2                            Artes cênicas  -1.56 -12.97 -87.36
# 3                           Bioinformática -12.60  -4.65 -85.59
# 4                               Bioquímica -15.26   5.81 -86.78
# 5        Ciência e engenharia de materiais  -8.89  -4.83 -83.67
# 6           Ciência, tecnologia e inovação  -2.07 -14.33 -85.04
# 7                        Ciências da saúde -18.41  -8.11 -87.18
# 8                   Ciências odontológicas   5.22 -15.98 -83.51
# 9                                   Design -19.10   0.16 -86.20
# 10                        Engenharia civil -12.92  -4.79 -87.23
# 11                  Engenharia de software -10.29 -15.08 -86.01
# 12                               Filosofia  -5.62 -13.43 -82.97
# 13  Gestão da informação e do conhecimento -16.55  -6.35 -85.77

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %%
percentual.style.text_gradient(cmap='RdYlGn', low=1, axis=1, vmax=0.1, vmin=0)\
                              .format('{:.2f} %', subset=['2018', '2019', '2022'])\
                              .set_table_styles(styles)\
                              .to_html('teste.html', doctype_html=True,
                                       table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING=5')
